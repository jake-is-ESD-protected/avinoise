# %%
from avinoise import prediction

file = "demo_data/20190131230038 - Glockenturm.wav"

pred, mel = prediction.predict(file)
prediction.evaluate(pred)
prediction.plot(pred, mel, name=file, visual_scale=5)
# Out:
# 2023-03-21 17:34:11.717998: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-21 17:34:11.718048: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-21 17:34:16.568778: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-21 17:34:16.568824: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-21 17:34:16.568845: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jtubuntusrvr): /proc/driver/nvidia/version does not exist
# ...
